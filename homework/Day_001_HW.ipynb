# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# random y = ax + b
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

# plot graph
plt.plot(x_lin, y ,'b. ', label = 'data point')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points and the prediction")
plt.legend(loc = 2)
plt.show()

# %%
# MAE (Mean Absolute Error)
def mean_absolute_error(current_value, predict_value):
    """
    calculate MAE
    Args:
        y: current value
        yp: predict value
   
    Return: 
        mae: MAE
        
    """
    mae = sum(abs(current_value - predict_value)) / len(current_value)
    return mae

MAE = mean_absolute_error(y, y_hat)
print("The mean absolute error is %.3f" %(MAE))
# Out:
# The mean absolute error is 12.142

# %%
# HW1
# MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2}

def mean_square_error(y, yp):
    frac = 1/len(y)
    x = sum(pow((y - yp),2))  
    mse = frac * x
    return mse

MSE = mean_square_error(y, y_hat)
print("The mean square error is %.3f" %(MSE))
# Out:
# The mean square error is 243.873

# %%
# Hw2
"""
Dataset: Tesla stock data from 2010 to 2020

1. 你選的這組資料為何重要
ans: 分析Tesla業績與行銷方式與股價的關係

2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
ans: 資料從證卷交易所取得

3. 蒐集而來的資料型態為何
ans: 結構化資料: 表格紀錄每月開盤價、收盤價、最高價、最低價、交易量

4. 這組資料想解決的問題如何評估
ans: 一位討論者: Yann Claudel 提出2個方法搭配進行分析
    1. RSI14 - a trend oscillator
    2. MACD (Moving Average Convergence-Divergence)
"""
# Out:
# '\nDataset: Tesla stock data from 2010 to 2020\n\n1. 你選的這組資料為何重要\nans: 分析Tesla業績與行銷方式與股價的關係\n\n2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)\nans: 資料從證卷交易所取得\n\n3. 蒐集而來的資料型態為何\nans: 結構化資料: 表格紀錄每月開盤價、收盤價、最高價、最低價、交易量\n\n4. 這組資料想解決的問題如何評估\nans: 一位討論者: Yann Claudel 提出2個方法搭配進行分析\n    1. RSI14 - a trend oscillator\n    2. MACD (Moving Average Convergence-Divergence)\n'

# %%
# HW3

"""
1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
ans: 考量: 載客地點(人流量)、提升顧客搭乘意願

2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
ans: 
    a.透過系統紀錄每次客人上下車地點、平均搭車時間，計算每分鐘計價格是否合理
    b.透過APP型式，設計問卷，得到顧客搭乘意願的前三原因順序為何?
    
3. 蒐集而來的資料型態為何   
ans: 結構化: 客人搭乘意願價格、載客時間成本

4. 你要回答的問題，其如何評估
ans: 分別算出客人意願與載客時間成本回歸曲線之最大交集點

"""
